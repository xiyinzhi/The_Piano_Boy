# %%
import glob
import pickle
import numpy as np
from music21 import converter, instrument, note, chord
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Activation
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint

def train_network():
    """ Train a Neural Network to generate music """
    network_input, network_output = prepare_sequences(get_notes())
    validate_input, validate_output = prepare_sequences(get_notes("test"))

    model = create_network(network_input)

    train(model, network_input, network_output, validate_input, validate_output)
    
    
def merge_notes(notes_dict, max_offset):
            
    ret = np.array([])
    for i in np.arange(0, max_offset, 0.5):
        pitches = np.zeros(88)
        if i in notes_dict:            
            for element in notes_dict[i]:            
                if isinstance(element, note.Note):
                    pitches[element.pitch.midi-21] = 1
                else:
                    for p in element.pitches:
                        pitches[p.midi-21] = 1    
        ret = np.append(ret, pitches)
    return ret
    

def get_notes(folder="midi_songs"):
    """ Get all the notes and chords from the midi files in the ./midi_songs directory """
    notes = np.array([])

    for file in glob.glob("{}/*.mid".format(folder)):
        midi = converter.parse(file)

        print("Parsing %s" % file)

        notes_to_parse = None

        try: # file has instrument parts
            s2 = instrument.partitionByInstrument(midi)
            notes_to_parse = s2.parts[0].recurse() 
        except: # file has notes in a flat structure
            notes_to_parse = midi.flat.notes
        notes_dict = {}
        max_offset = 0
        for element in notes_to_parse:        
            if isinstance(element, note.Note) or isinstance(element, chord.Chord):  
                if element.offset not in notes_dict:
                    notes_dict[element.offset] = []
                notes_dict[element.offset].append(element)
                max_offset = element.offset    
        ret = merge_notes(notes_dict, max_offset)
        #print(len(ret))
        notes = np.append(notes, ret)
        #print(len(notes))
    row = notes.size / 88
    notes = notes.reshape(int(row), 88)
    #with open('data/notes', 'wb') as filepath:
        #pickle.dump(notes, filepath)
    
    return notes

def prepare_sequences(notes):
    """ Prepare the sequences used by the Neural Network """
    sequence_length = 100

    network_input = []
    network_output = []

    # create input sequences and the corresponding outputs
    for i in range(0, len(notes) - sequence_length, 1):
        sequence_in = notes[i:i + sequence_length]
        sequence_out = notes[i + sequence_length]
        network_input.append(sequence_in)
        network_output.append(sequence_out)

    n_patterns = len(network_input)
    #print(n_patterns)
    # reshape the input into a format compatible with LSTM layers
    network_input = np.reshape(network_input, (n_patterns, sequence_length, 88))
    network_output = np.reshape(network_output, (n_patterns, 88))
    return (network_input, network_output)

def create_network(network_input):
    """ create the structure of the neural network """
    model = Sequential()
    model.add(LSTM(
        512,
        input_shape=(network_input.shape[1], network_input.shape[2]),
        return_sequences=True
    ))
    model.add(Dropout(0.3))
    model.add(LSTM(512, return_sequences=True))
    model.add(Dropout(0.3))
    model.add(LSTM(512))
    model.add(Dense(256))
    model.add(Dropout(0.3))
    model.add(Dense(88))
    #model.add(Activation('sigmoid'))
    #model.compile(loss='binary_crossentropy', optimizer='rmsprop')
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    return model

def train(model, network_input, network_output, validate_input,validate_output):
    """ train the neural network """
    filepath = "weights-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5"
    checkpoint = ModelCheckpoint(
        filepath,
        monitor='loss',
        verbose=0,
        save_best_only=True,
        mode='min'
    )
    callbacks_list = [checkpoint]
    #print(network_input.shape)
    #print(network_output.shape)
    model.fit(network_input, network_output, 
              validation_data=(validate_input,validate_output), 
              epochs=200, batch_size=64, 
              callbacks=callbacks_list)
# Out:
# Using TensorFlow backend.

# %%
#n = get_notes()

# %%
train_network()
# Out:
# Parsing midi_songs/Ff7-Cinco.mid
# Parsing midi_songs/waltz_de_choco.mid
# Parsing midi_songs/Ff4-BattleLust.mid
# Parsing midi_songs/dontbeafraid.mid
# Parsing midi_songs/electric_de_chocobo.mid
# Parsing midi_songs/costadsol.mid
# Parsing midi_songs/Ff7-Jenova_Absolute.mid
# Parsing midi_songs/tifap.mid
# Parsing midi_songs/Still_Alive-1.mid
# Parsing midi_songs/bcm.mid
# Parsing midi_songs/ff7-mainmidi.mid
# Parsing midi_songs/ultros.mid
# Parsing midi_songs/0fithos.mid
# Parsing midi_songs/mining.mid
# Parsing midi_songs/Ff7-One_Winged.mid
# Parsing midi_songs/FFIX_Piano.mid
# Parsing midi_songs/balamb.mid
# Parsing midi_songs/caitsith.mid
# Parsing midi_songs/path_of_repentance.mid
# Parsing midi_songs/ff1battp.mid
# Parsing midi_songs/Finalfantasy6fanfarecomplete.mid
# Parsing midi_songs/Oppressed.mid
# Parsing midi_songs/relmstheme-piano.mid
# Parsing midi_songs/ff4-fight1.mid
# Parsing midi_songs/Finalfantasy5gilgameshp.mid
# Parsing midi_songs/FF4.mid
# Parsing midi_songs/Final_Fantasy_Matouyas_Cave_Piano.mid
# Parsing midi_songs/Eternal_Harvest.mid
# Parsing midi_songs/thoughts.mid
# Parsing midi_songs/ff7themep.mid
# Parsing midi_songs/goldsaucer.mid
# Parsing midi_songs/Gold_Silver_Rival_Battle.mid
# Parsing midi_songs/Fyw_piano.mid
# Parsing midi_songs/EyesOnMePiano.mid
# Parsing midi_songs/BlueStone_LastDungeon.mid
# Parsing midi_songs/ff4-airship.mid
# Parsing midi_songs/sobf.mid
# Parsing midi_songs/ff4pclov.mid
# Parsing midi_songs/z_aeristhemepiano.mid
# Parsing midi_songs/HighwindTakestotheSkies.mid
# Parsing midi_songs/ahead_on_our_way_piano.mid
# Parsing midi_songs/Suteki_Da_Ne_(Piano_Version).mid
# Parsing midi_songs/figaro.mid
# Parsing midi_songs/FFX_-_Ending_Theme_(Piano_Version)_-_by_Angel_FF.mid
# Parsing midi_songs/Kingdom_Hearts_Traverse_Town.mid
# Parsing midi_songs/cosmo.mid
# Parsing midi_songs/8.mid
# Parsing midi_songs/FFIII_Edgar_And_Sabin_Piano.mid
# Parsing midi_songs/FF3_Battle_(Piano).mid
# Parsing midi_songs/Zelda_Overworld.mid
# Parsing midi_songs/braska.mid
# Parsing midi_songs/sandy.mid
# Parsing midi_songs/ff4_piano_collections-main_theme.mid
# Parsing midi_songs/JENOVA.mid
# Parsing midi_songs/ViviinAlexandria.mid
# Parsing midi_songs/ff11_awakening_piano.mid
# Parsing midi_songs/Fiend_Battle_(Piano).mid
# Parsing midi_songs/Fierce_Battle_(Piano).mid
# Parsing midi_songs/great_war.mid
# Parsing midi_songs/FF6epitaph_piano.mid
# Parsing midi_songs/dayafter.mid
# Parsing midi_songs/ff6shap.mid
# Parsing midi_songs/VincentPiano.mid
# Parsing midi_songs/Life_Stream.mid
# Parsing midi_songs/FFIXQuMarshP.mid
# Parsing midi_songs/fortresscondor.mid
# Parsing midi_songs/FFVII_BATTLE.mid
# Parsing midi_songs/FF3_Third_Phase_Final_(Piano).mid
# Parsing midi_songs/AT.mid
# Parsing midi_songs/In_Zanarkand.mid
# Parsing midi_songs/ff8-lfp.mid
# Parsing midi_songs/Cids.mid
# Parsing midi_songs/sera_.mid
# Parsing midi_songs/FF8_Shuffle_or_boogie_pc.mid
# Parsing midi_songs/Rachel_Piano_tempofix.mid
# Parsing midi_songs/gerudo.mid
# Parsing midi_songs/ff4-town.mid
# Parsing midi_songs/DOS.mid
# Parsing midi_songs/OTD5YA.mid
# Parsing midi_songs/redwings.mid
# Parsing midi_songs/pkelite4.mid
# Parsing midi_songs/tpirtsd-piano.mid
# Parsing midi_songs/rufus.mid
# Parsing midi_songs/roseofmay-piano.mid
# Parsing midi_songs/traitor.mid
# Parsing midi_songs/Rydia_pc.mid
# Parsing midi_songs/ultimafro.mid
# Parsing midi_songs/decisive.mid
# Parsing midi_songs/Final_Fantasy_7_-_Judgement_Day_Piano.mid
# Parsing midi_songs/thenightmarebegins.mid
# Parsing test/Kingdom_Hearts_Dearly_Beloved.mid
# Parsing test/lurk_in_dark.mid
# Train on 46310 samples, validate on 400 samples
# Epoch 1/200
# 46310/46310 [==============================] - 170s 4ms/step - loss: 4.9077 - acc: 0.1104 - val_loss: 2.6053 - val_acc: 0.0225
# Epoch 2/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 4.4983 - acc: 0.1450 - val_loss: 2.7146 - val_acc: 0.0150
# Epoch 3/200
# 46310/46310 [==============================] - 171s 4ms/step - loss: 4.3021 - acc: 0.1604 - val_loss: 2.7137 - val_acc: 0.0075
# Epoch 4/200
# 46310/46310 [==============================] - 170s 4ms/step - loss: 4.0526 - acc: 0.1947 - val_loss: 2.6567 - val_acc: 0.0175
# Epoch 5/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 3.7505 - acc: 0.2414 - val_loss: 2.7364 - val_acc: 0.0125
# Epoch 6/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 3.4350 - acc: 0.2870 - val_loss: 2.8081 - val_acc: 0.0200
# Epoch 7/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 3.1386 - acc: 0.3261 - val_loss: 2.9507 - val_acc: 0.0200
# Epoch 8/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 2.8801 - acc: 0.3575 - val_loss: 3.0169 - val_acc: 0.0075
# Epoch 9/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 2.6783 - acc: 0.3879 - val_loss: 2.9649 - val_acc: 0.0175
# Epoch 10/200
# 46310/46310 [==============================] - 170s 4ms/step - loss: 2.5196 - acc: 0.4054 - val_loss: 3.1061 - val_acc: 0.0325
# Epoch 11/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 2.3985 - acc: 0.4213 - val_loss: 3.1137 - val_acc: 0.0275
# Epoch 12/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 2.3026 - acc: 0.4329 - val_loss: 3.2946 - val_acc: 0.0150
# Epoch 13/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 2.2209 - acc: 0.4401 - val_loss: 3.3067 - val_acc: 0.0250
# Epoch 14/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 2.1572 - acc: 0.4491 - val_loss: 3.2282 - val_acc: 0.0150
# Epoch 15/200
# 46310/46310 [==============================] - 173s 4ms/step - loss: 2.1124 - acc: 0.4539 - val_loss: 3.2689 - val_acc: 0.0250
# Epoch 16/200
# 46310/46310 [==============================] - 183s 4ms/step - loss: 2.0637 - acc: 0.4582 - val_loss: 3.1543 - val_acc: 0.0200
# Epoch 17/200
# 46310/46310 [==============================] - 177s 4ms/step - loss: 2.0203 - acc: 0.4639 - val_loss: 3.3205 - val_acc: 0.0125
# Epoch 18/200
# 46310/46310 [==============================] - 172s 4ms/step - loss: 1.9920 - acc: 0.4683 - val_loss: 3.2471 - val_acc: 0.0275
# Epoch 19/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.9646 - acc: 0.4695 - val_loss: 3.3375 - val_acc: 0.0250
# Epoch 20/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.9370 - acc: 0.4735 - val_loss: 3.2670 - val_acc: 0.0175
# Epoch 21/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.9207 - acc: 0.4742 - val_loss: 3.2154 - val_acc: 0.0175
# Epoch 22/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.8989 - acc: 0.4741 - val_loss: 3.2779 - val_acc: 0.0200
# Epoch 23/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.8693 - acc: 0.4748 - val_loss: 3.3026 - val_acc: 0.0175
# Epoch 24/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.8572 - acc: 0.4796 - val_loss: 3.4204 - val_acc: 0.0125
# Epoch 25/200
# 46310/46310 [==============================] - 178s 4ms/step - loss: 1.8438 - acc: 0.4780 - val_loss: 3.4585 - val_acc: 0.0100
# Epoch 26/200
# 46310/46310 [==============================] - 184s 4ms/step - loss: 1.8269 - acc: 0.4812 - val_loss: 3.3790 - val_acc: 0.0125
# Epoch 27/200
# 46310/46310 [==============================] - 176s 4ms/step - loss: 1.8154 - acc: 0.4811 - val_loss: 3.5701 - val_acc: 0.0050
# Epoch 28/200
# 46310/46310 [==============================] - 175s 4ms/step - loss: 1.8034 - acc: 0.4829 - val_loss: 3.4966 - val_acc: 0.0175
# Epoch 29/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.7917 - acc: 0.4828 - val_loss: 3.4214 - val_acc: 0.0175
# Epoch 30/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.7777 - acc: 0.4828 - val_loss: 3.5708 - val_acc: 0.0200
# Epoch 31/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.7722 - acc: 0.4833 - val_loss: 3.3545 - val_acc: 0.0175
# Epoch 32/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.7635 - acc: 0.4839 - val_loss: 3.3699 - val_acc: 0.0200
# Epoch 33/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.7571 - acc: 0.4835 - val_loss: 3.5427 - val_acc: 0.0075
# Epoch 34/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.7410 - acc: 0.4851 - val_loss: 3.4174 - val_acc: 0.0100
# Epoch 35/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.7355 - acc: 0.4851 - val_loss: 3.3218 - val_acc: 0.0125
# Epoch 36/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.7279 - acc: 0.4866 - val_loss: 3.2753 - val_acc: 0.0150
# Epoch 37/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.7249 - acc: 0.4864 - val_loss: 3.4214 - val_acc: 0.0125
# Epoch 38/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.7153 - acc: 0.4855 - val_loss: 3.6023 - val_acc: 0.0250
# Epoch 39/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.7088 - acc: 0.4861 - val_loss: 3.2016 - val_acc: 0.0100
# Epoch 40/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.7085 - acc: 0.4870 - val_loss: 3.2329 - val_acc: 0.0200
# Epoch 41/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6970 - acc: 0.4866 - val_loss: 3.2531 - val_acc: 0.0175
# Epoch 42/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6922 - acc: 0.4859 - val_loss: 3.1950 - val_acc: 0.0175
# Epoch 43/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6843 - acc: 0.4863 - val_loss: 3.1534 - val_acc: 0.0275
# Epoch 44/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6801 - acc: 0.4873 - val_loss: 3.1216 - val_acc: 0.0250
# Epoch 45/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6732 - acc: 0.4871 - val_loss: 3.2906 - val_acc: 0.0050
# Epoch 46/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6718 - acc: 0.4884 - val_loss: 3.2883 - val_acc: 0.0150
# Epoch 47/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6679 - acc: 0.4868 - val_loss: 3.1940 - val_acc: 0.0225
# Epoch 48/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6582 - acc: 0.4856 - val_loss: 3.3497 - val_acc: 0.0075
# Epoch 49/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6562 - acc: 0.4880 - val_loss: 3.2917 - val_acc: 0.0125
# Epoch 50/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.6532 - acc: 0.4875 - val_loss: 3.3969 - val_acc: 0.0150
# Epoch 51/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6514 - acc: 0.4902 - val_loss: 3.3151 - val_acc: 0.0225
# Epoch 52/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.6462 - acc: 0.4869 - val_loss: 3.2554 - val_acc: 0.0075
# Epoch 53/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6455 - acc: 0.4890 - val_loss: 3.2624 - val_acc: 0.0150
# Epoch 54/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6359 - acc: 0.4901 - val_loss: 3.3350 - val_acc: 0.0200
# Epoch 55/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6308 - acc: 0.4876 - val_loss: 3.1365 - val_acc: 0.0150
# Epoch 56/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6353 - acc: 0.4882 - val_loss: 3.1371 - val_acc: 0.0200
# Epoch 57/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6288 - acc: 0.4881 - val_loss: 3.2161 - val_acc: 0.0225
# Epoch 58/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6219 - acc: 0.4876 - val_loss: 3.2250 - val_acc: 0.0225
# Epoch 59/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6212 - acc: 0.4866 - val_loss: 3.2078 - val_acc: 0.0200
# Epoch 60/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6178 - acc: 0.4876 - val_loss: 3.0667 - val_acc: 0.0125
# Epoch 61/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6150 - acc: 0.4891 - val_loss: 3.3033 - val_acc: 0.0175
# Epoch 62/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6084 - acc: 0.4870 - val_loss: 3.2283 - val_acc: 0.0125
# Epoch 63/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6064 - acc: 0.4899 - val_loss: 3.2750 - val_acc: 0.0150
# Epoch 64/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6047 - acc: 0.4896 - val_loss: 3.2630 - val_acc: 0.0125
# Epoch 65/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.6033 - acc: 0.4885 - val_loss: 3.1847 - val_acc: 0.0100
# Epoch 66/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5995 - acc: 0.4898 - val_loss: 3.1657 - val_acc: 0.0200
# Epoch 67/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5969 - acc: 0.4882 - val_loss: 3.1486 - val_acc: 0.0225
# Epoch 68/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5931 - acc: 0.4882 - val_loss: 3.1138 - val_acc: 0.0200
# Epoch 69/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5927 - acc: 0.4889 - val_loss: 3.1184 - val_acc: 0.0200
# Epoch 70/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5905 - acc: 0.4878 - val_loss: 3.3580 - val_acc: 0.0150
# Epoch 71/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5852 - acc: 0.4874 - val_loss: 3.0932 - val_acc: 0.0225
# Epoch 72/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5838 - acc: 0.4882 - val_loss: 3.2504 - val_acc: 0.0100
# Epoch 73/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5828 - acc: 0.4878 - val_loss: 3.1263 - val_acc: 0.0300
# Epoch 74/200
# 46310/46310 [==============================] - 170s 4ms/step - loss: 1.5789 - acc: 0.4903 - val_loss: 3.0962 - val_acc: 0.0050
# Epoch 75/200
# 46310/46310 [==============================] - 172s 4ms/step - loss: 1.5801 - acc: 0.4870 - val_loss: 3.1118 - val_acc: 0.0125
# Epoch 76/200
# 46310/46310 [==============================] - 171s 4ms/step - loss: 1.5783 - acc: 0.4891 - val_loss: 3.1375 - val_acc: 0.0075
# Epoch 77/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5748 - acc: 0.4897 - val_loss: 3.0577 - val_acc: 0.0075
# Epoch 78/200
# 46310/46310 [==============================] - 170s 4ms/step - loss: 1.5753 - acc: 0.4883 - val_loss: 3.0859 - val_acc: 0.0125
# Epoch 79/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.5713 - acc: 0.4880 - val_loss: 3.0717 - val_acc: 0.0075
# Epoch 80/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5699 - acc: 0.4891 - val_loss: 3.0431 - val_acc: 0.0150
# Epoch 81/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5713 - acc: 0.4882 - val_loss: 3.0941 - val_acc: 0.0150
# Epoch 82/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5634 - acc: 0.4900 - val_loss: 3.0289 - val_acc: 0.0100
# Epoch 83/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5596 - acc: 0.4896 - val_loss: 3.1538 - val_acc: 0.0075
# Epoch 84/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5654 - acc: 0.4885 - val_loss: 2.9672 - val_acc: 0.0125
# Epoch 85/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5591 - acc: 0.4896 - val_loss: 3.0601 - val_acc: 0.0000e+00
# Epoch 86/200
# 46310/46310 [==============================] - 170s 4ms/step - loss: 1.5597 - acc: 0.4889 - val_loss: 3.1132 - val_acc: 0.0150
# Epoch 87/200
# 46310/46310 [==============================] - 170s 4ms/step - loss: 1.5553 - acc: 0.4888 - val_loss: 3.0620 - val_acc: 0.0050
# Epoch 88/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5579 - acc: 0.4896 - val_loss: 3.0602 - val_acc: 0.0125
# Epoch 89/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5511 - acc: 0.4895 - val_loss: 3.1287 - val_acc: 0.0075
# Epoch 90/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5537 - acc: 0.4894 - val_loss: 3.2732 - val_acc: 0.0150
# Epoch 91/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5505 - acc: 0.4886 - val_loss: 3.1159 - val_acc: 0.0050
# Epoch 92/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.5445 - acc: 0.4891 - val_loss: 3.1223 - val_acc: 0.0075
# Epoch 93/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.5462 - acc: 0.4895 - val_loss: 3.0694 - val_acc: 0.0100
# Epoch 94/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.5454 - acc: 0.4900 - val_loss: 3.0842 - val_acc: 0.0125
# Epoch 95/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.5403 - acc: 0.4891 - val_loss: 3.1361 - val_acc: 0.0150
# Epoch 96/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5429 - acc: 0.4891 - val_loss: 3.0324 - val_acc: 0.0125
# Epoch 97/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5430 - acc: 0.4884 - val_loss: 3.1258 - val_acc: 0.0100
# Epoch 98/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5378 - acc: 0.4863 - val_loss: 3.0523 - val_acc: 0.0200
# Epoch 99/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5387 - acc: 0.4886 - val_loss: 3.0728 - val_acc: 0.0150
# Epoch 100/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5357 - acc: 0.4905 - val_loss: 3.2041 - val_acc: 0.0025
# Epoch 101/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5372 - acc: 0.4896 - val_loss: 3.0838 - val_acc: 0.0100
# Epoch 102/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5333 - acc: 0.4892 - val_loss: 3.1040 - val_acc: 0.0075
# Epoch 103/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5302 - acc: 0.4877 - val_loss: 3.1000 - val_acc: 0.0200
# Epoch 104/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5337 - acc: 0.4894 - val_loss: 3.0554 - val_acc: 0.0000e+00
# Epoch 105/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5338 - acc: 0.4906 - val_loss: 3.0061 - val_acc: 0.0025
# Epoch 106/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5315 - acc: 0.4881 - val_loss: 3.0594 - val_acc: 0.0125
# Epoch 107/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5303 - acc: 0.4892 - val_loss: 3.1078 - val_acc: 0.0075
# Epoch 108/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5270 - acc: 0.4882 - val_loss: 3.1117 - val_acc: 0.0075
# Epoch 109/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5289 - acc: 0.4913 - val_loss: 3.0273 - val_acc: 0.0050
# Epoch 110/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5265 - acc: 0.4903 - val_loss: 3.0764 - val_acc: 0.0050
# Epoch 111/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.5218 - acc: 0.4894 - val_loss: 3.1146 - val_acc: 0.0050
# Epoch 112/200
# 46310/46310 [==============================] - 170s 4ms/step - loss: 1.5241 - acc: 0.4893 - val_loss: 3.1225 - val_acc: 0.0050
# Epoch 113/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.5238 - acc: 0.4897 - val_loss: 3.0771 - val_acc: 0.0075
# Epoch 114/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5208 - acc: 0.4891 - val_loss: 3.0852 - val_acc: 0.0050
# Epoch 115/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5213 - acc: 0.4895 - val_loss: 3.1647 - val_acc: 0.0075
# Epoch 116/200
# 46310/46310 [==============================] - 174s 4ms/step - loss: 1.5197 - acc: 0.4886 - val_loss: 3.1029 - val_acc: 0.0050
# Epoch 117/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5224 - acc: 0.4898 - val_loss: 3.1495 - val_acc: 0.0100
# Epoch 118/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5162 - acc: 0.4884 - val_loss: 3.0072 - val_acc: 0.0075
# Epoch 119/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5183 - acc: 0.4899 - val_loss: 3.0083 - val_acc: 0.0000e+00
# Epoch 120/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5164 - acc: 0.4896 - val_loss: 3.0152 - val_acc: 0.0050
# Epoch 121/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5141 - acc: 0.4881 - val_loss: 3.0718 - val_acc: 0.0075
# Epoch 122/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5174 - acc: 0.4881 - val_loss: 2.9706 - val_acc: 0.0075
# Epoch 123/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5117 - acc: 0.4894 - val_loss: 3.1073 - val_acc: 0.0025
# Epoch 124/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5118 - acc: 0.4877 - val_loss: 3.0026 - val_acc: 0.0050
# Epoch 125/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5117 - acc: 0.4895 - val_loss: 3.0593 - val_acc: 0.0150
# Epoch 126/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5109 - acc: 0.4891 - val_loss: 2.9972 - val_acc: 0.0075
# Epoch 127/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5084 - acc: 0.4883 - val_loss: 3.0785 - val_acc: 0.0075
# Epoch 128/200
# 46310/46310 [==============================] - 170s 4ms/step - loss: 1.5092 - acc: 0.4899 - val_loss: 2.9886 - val_acc: 0.0000e+00
# Epoch 129/200
# 46310/46310 [==============================] - 171s 4ms/step - loss: 1.5101 - acc: 0.4878 - val_loss: 3.0261 - val_acc: 0.0050
# Epoch 130/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5075 - acc: 0.4903 - val_loss: 3.0981 - val_acc: 0.0075
# Epoch 131/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5062 - acc: 0.4912 - val_loss: 3.0001 - val_acc: 0.0025
# Epoch 132/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5110 - acc: 0.4880 - val_loss: 3.1018 - val_acc: 0.0125
# Epoch 133/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5055 - acc: 0.4895 - val_loss: 3.0760 - val_acc: 0.0100
# Epoch 134/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5059 - acc: 0.4879 - val_loss: 3.0541 - val_acc: 0.0025
# Epoch 135/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5050 - acc: 0.4874 - val_loss: 2.9801 - val_acc: 0.0075
# Epoch 136/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5018 - acc: 0.4907 - val_loss: 3.0887 - val_acc: 0.0050
# Epoch 137/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5009 - acc: 0.4906 - val_loss: 3.0575 - val_acc: 0.0075
# Epoch 138/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5033 - acc: 0.4895 - val_loss: 3.0074 - val_acc: 0.0175
# Epoch 139/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5006 - acc: 0.4910 - val_loss: 3.0300 - val_acc: 0.0100
# Epoch 140/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.4996 - acc: 0.4891 - val_loss: 3.0521 - val_acc: 0.0125
# Epoch 141/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.4985 - acc: 0.4892 - val_loss: 3.0590 - val_acc: 0.0100
# Epoch 142/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.4983 - acc: 0.4891 - val_loss: 3.0903 - val_acc: 0.0175
# Epoch 143/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.5013 - acc: 0.4902 - val_loss: 3.0603 - val_acc: 0.0050
# Epoch 144/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.4958 - acc: 0.4880 - val_loss: 3.0209 - val_acc: 0.0050
# Epoch 145/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.4973 - acc: 0.4906 - val_loss: 3.0568 - val_acc: 0.0050
# Epoch 146/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.4996 - acc: 0.4892 - val_loss: 3.0160 - val_acc: 0.0025
# Epoch 147/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4976 - acc: 0.4907 - val_loss: 2.9416 - val_acc: 0.0100
# Epoch 148/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4960 - acc: 0.4906 - val_loss: 2.9257 - val_acc: 0.0075
# Epoch 149/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4960 - acc: 0.4881 - val_loss: 3.0352 - val_acc: 0.0075
# Epoch 150/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.5425 - acc: 0.4863 - val_loss: 3.0496 - val_acc: 0.0050
# Epoch 151/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.5511 - acc: 0.4845 - val_loss: 2.9776 - val_acc: 0.0000e+00
# Epoch 152/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5030 - acc: 0.4872 - val_loss: 3.0502 - val_acc: 0.0025
# Epoch 153/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.4999 - acc: 0.4905 - val_loss: 3.0012 - val_acc: 0.0075
# Epoch 154/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.4988 - acc: 0.4910 - val_loss: 3.0308 - val_acc: 0.0025
# Epoch 155/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.4967 - acc: 0.4888 - val_loss: 3.0775 - val_acc: 0.0100
# Epoch 156/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.5003 - acc: 0.4897 - val_loss: 3.0655 - val_acc: 0.0150
# Epoch 157/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.4942 - acc: 0.4902 - val_loss: 3.0661 - val_acc: 0.0125
# Epoch 158/200
# 46310/46310 [==============================] - 171s 4ms/step - loss: 1.4944 - acc: 0.4897 - val_loss: 3.0624 - val_acc: 0.0100
# Epoch 159/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.4914 - acc: 0.4881 - val_loss: 3.0593 - val_acc: 0.0025
# Epoch 160/200
# 46310/46310 [==============================] - 170s 4ms/step - loss: 1.4951 - acc: 0.4899 - val_loss: 3.0188 - val_acc: 0.0025
# Epoch 161/200
# 46310/46310 [==============================] - 168s 4ms/step - loss: 1.4902 - acc: 0.4903 - val_loss: 2.9534 - val_acc: 0.0075
# Epoch 162/200
# 46310/46310 [==============================] - 171s 4ms/step - loss: 1.4898 - acc: 0.4886 - val_loss: 3.0444 - val_acc: 0.0050
# Epoch 163/200
# 46310/46310 [==============================] - 174s 4ms/step - loss: 1.4896 - acc: 0.4900 - val_loss: 2.9983 - val_acc: 0.0000e+00
# Epoch 164/200
# 46310/46310 [==============================] - 169s 4ms/step - loss: 1.4913 - acc: 0.4902 - val_loss: 3.1070 - val_acc: 0.0025
# Epoch 165/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4877 - acc: 0.4896 - val_loss: 3.0865 - val_acc: 0.0025
# Epoch 166/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4902 - acc: 0.4888 - val_loss: 2.9945 - val_acc: 0.0075
# Epoch 167/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4881 - acc: 0.4908 - val_loss: 3.0678 - val_acc: 0.0025
# Epoch 168/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4890 - acc: 0.4907 - val_loss: 2.9697 - val_acc: 0.0025
# Epoch 169/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4898 - acc: 0.4897 - val_loss: 2.9729 - val_acc: 0.0000e+00
# Epoch 170/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4855 - acc: 0.4900 - val_loss: 2.9531 - val_acc: 0.0000e+00
# Epoch 171/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4848 - acc: 0.4879 - val_loss: 2.9932 - val_acc: 0.0000e+00
# Epoch 172/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4862 - acc: 0.4875 - val_loss: 3.2007 - val_acc: 0.0075
# Epoch 173/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4856 - acc: 0.4896 - val_loss: 2.9547 - val_acc: 0.0050
# Epoch 174/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4881 - acc: 0.4889 - val_loss: 3.4519 - val_acc: 0.0025
# Epoch 175/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4834 - acc: 0.4888 - val_loss: 2.9781 - val_acc: 0.0050
# Epoch 176/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4855 - acc: 0.4905 - val_loss: 3.0394 - val_acc: 0.0025
# Epoch 177/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4851 - acc: 0.4892 - val_loss: 2.9999 - val_acc: 0.0000e+00
# Epoch 178/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4827 - acc: 0.4909 - val_loss: 2.9469 - val_acc: 0.0025
# Epoch 179/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4817 - acc: 0.4893 - val_loss: 3.0903 - val_acc: 0.0000e+00
# Epoch 180/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4815 - acc: 0.4884 - val_loss: 2.9965 - val_acc: 0.0125
# Epoch 181/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4820 - acc: 0.4906 - val_loss: 2.9166 - val_acc: 0.0050
# Epoch 182/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4843 - acc: 0.4882 - val_loss: 2.9807 - val_acc: 0.0000e+00
# Epoch 183/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4825 - acc: 0.4897 - val_loss: 3.0652 - val_acc: 0.0025
# Epoch 184/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4827 - acc: 0.4910 - val_loss: 3.0632 - val_acc: 0.0025
# Epoch 185/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4779 - acc: 0.4887 - val_loss: 3.0308 - val_acc: 0.0100
# Epoch 186/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4787 - acc: 0.4884 - val_loss: 3.0247 - val_acc: 0.0100
# Epoch 187/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4813 - acc: 0.4886 - val_loss: 2.9277 - val_acc: 0.0125
# Epoch 188/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4806 - acc: 0.4892 - val_loss: 3.0431 - val_acc: 0.0150
# Epoch 189/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4798 - acc: 0.4901 - val_loss: 3.0315 - val_acc: 0.0150
# Epoch 190/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4741 - acc: 0.4870 - val_loss: 2.9203 - val_acc: 0.0075
# Epoch 191/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4742 - acc: 0.4872 - val_loss: 2.9114 - val_acc: 0.0175
# Epoch 192/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4719 - acc: 0.4902 - val_loss: 3.1045 - val_acc: 0.0075
# Epoch 193/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4764 - acc: 0.4892 - val_loss: 3.1023 - val_acc: 0.0150
# Epoch 194/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4724 - acc: 0.4877 - val_loss: 2.9924 - val_acc: 0.0125
# Epoch 195/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4656 - acc: 0.4907 - val_loss: 3.0359 - val_acc: 0.0100
# Epoch 196/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4693 - acc: 0.4889 - val_loss: 3.0008 - val_acc: 0.0075
# Epoch 197/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4733 - acc: 0.4897 - val_loss: 3.0306 - val_acc: 0.0025
# Epoch 198/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4803 - acc: 0.4883 - val_loss: 2.9739 - val_acc: 0.0100
# Epoch 199/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4775 - acc: 0.4886 - val_loss: 3.0022 - val_acc: 0.0100
# Epoch 200/200
# 46310/46310 [==============================] - 167s 4ms/step - loss: 1.4763 - acc: 0.4898 - val_loss: 2.8954 - val_acc: 0.0050

# %%
""" This module generates notes for a midi file using the
    trained neural network """
import pickle
import numpy as np
from music21 import instrument, note, stream, chord, pitch
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Activation

sequence_length = 100
def get_notes(folder="test"):
    """ Get all the notes and chords from the midi files in the ./midi_songs directory """
    notes = np.array([])

    for file in glob.glob("{}/*.mid".format(folder)):
        midi = converter.parse(file)

        print("Parsing %s" % file)

        notes_to_parse = None

        try: # file has instrument parts
            s2 = instrument.partitionByInstrument(midi)
            notes_to_parse = s2.parts[0].recurse() 
        except: # file has notes in a flat structure
            notes_to_parse = midi.flat.notes
        notes_dict = {}
        max_offset = 0
        for element in notes_to_parse:        
            if isinstance(element, note.Note) or isinstance(element, chord.Chord):  
                if element.offset not in notes_dict:
                    notes_dict[element.offset] = []
                notes_dict[element.offset].append(element)
                max_offset = element.offset    
        ret = merge_notes(notes_dict, max_offset)
        #print(len(ret))
        notes = np.append(notes, ret)
        #print(len(notes))
    row = notes.size / 88
    notes = notes.reshape(int(row), 88)
    with open('data/notes', 'wb') as filepath:
        pickle.dump(notes, filepath)
    
    return notes

def generate():
    """ Generate a piano midi file """
    #load the notes used to train the model
    #with open('data/notes', 'rb') as filepath:
    #    notes = pickle.load(filepath)

    network_input = prepare_sequences(get_notes())
    model = create_network()
    prediction_output = generate_notes(model, network_input)
    create_midi(prediction_output)

def prepare_sequences(notes):
    """ Prepare the sequences used by the Neural Network """
    
    network_input = []

    # create input sequences and the corresponding outputs
    for i in range(0, len(notes) - sequence_length, 1):
        sequence_in = notes[i:i + sequence_length]
        network_input.append(sequence_in)

    return network_input

def create_network():
    """ create the structure of the neural network """
    model = Sequential()
    model.add(LSTM(
        512,
        input_shape=(sequence_length, 88),
        return_sequences=True
    ))
    model.add(Dropout(0.3))
    model.add(LSTM(512, return_sequences=True))
    model.add(Dropout(0.3))
    model.add(LSTM(512))
    model.add(Dense(256))
    model.add(Dropout(0.3))
    model.add(Dense(88))
    #model.add(Activation('sigmoid'))
    #model.compile(loss='binary_crossentropy', optimizer='rmsprop')
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop')
    # Load the weights to each node
    model.load_weights('weights-improvement-195-1.4606-bigger.hdf5')
    return model

def generate_notes(model, network_input):
    """ Generate notes from the neural network based on a sequence of notes """
    # pick a random sequence from the input as a starting point for the prediction
    start = np.random.randint(0, len(network_input)-1)
    pattern = network_input[start]
    prediction_output = []
    threshold = 0.5
    # generate 500 notes
    for note_index in range(500):
        prediction_input = np.reshape(pattern, (1, sequence_length, 88))
        prediction = model.predict(prediction_input, verbose=0)[0]
        index = np.argmax(prediction)
        prediction = np.zeros(88)
        prediction[index] = 1
        pattern = np.append(pattern, prediction)[88:]    
        #print(prediction)
        prediction_output.append(prediction)
    return prediction_output

import time
current_time = lambda: int(round(time.time()))

def create_midi(prediction_output):
    """ convert the output from the prediction to notes and create a midi file
        from the notes """
    offset = 0
    output_notes = []
    #print(prediction_output)
    # create note and chord objects based on the values generated by the model
    for pattern in prediction_output:
        indices = np.where(pattern > 0)[0]
        if len(indices) > 0:
            notes = []
            for index in indices:
                n = note.Note()
                p = pitch.Pitch()
                p.midi = index + 21
                n.pitch = p
                n.storedInstrument = instrument.Piano()
                notes.append(n)
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
       
        # increase offset each iteration so that notes do not stack
        offset += 0.5

    midi_stream = stream.Stream(output_notes)

    midi_stream.write('midi', fp='40_sentence_05_test_output_{}.mid'.format(current_time()))

# %%
for i in range(20):
    generate()
# Out:
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
# Parsing test/chpn_op25_e4.mid
# Parsing test/chpn_op25_e1.mid
# Parsing test/chpn_op25_e3.mid
# Parsing test/chpn_op25_e2.mid
